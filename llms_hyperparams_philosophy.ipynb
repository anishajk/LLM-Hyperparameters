# %% [markdown]
# Homework 2: LLMs Experiments & Hyperparameters, LLMs Philosophy
# ----
#
# Due date: September 20th, 2023
#
# Points: 60
#
# Goals:
# - explore and understand some of the hyperparameters available to you with LLMs
# - consider more deeply the philosophy of AI and LLMs
#
#
# Complete in groups of: __one (individually)__
#
# Allowed python modules:
# - You are not allowed to use any library's implementation of `softmax`. You may use the `random` and `numpy` libraries in this assignment.
#
# Instructions:
# - Complete outlined problems in this notebook.
# - When you have finished, __clear the kernel__ and __run__ your notebook "fresh" from top to bottom. Ensure that there are __no errors__.
#     - If a problem asks for you to write code that does result in an error (as in, the answer to the problem is an error), leave the code in your notebook but commented out so that running from top to bottom does not result in any errors.
# - Double check that you have completed Task 0.
# - Submit your work on Gradescope.
# - Double check that your submission on Gradescope looks like you believe it should __and__ that all partners are included (for partner work).
#
# 6120 students: complete __all__ problems.
#
# 4120 students: you are not required to complete problems marked "CS 6120 REQUIRED". If you complete these you will not get extra credit. We will not take points off if you attempt these problems and do not succeed.

# %% [markdown]
# Task 0: Name, References, Reflection (5 points)
# ---
#
# TODO: complete this section
#
# Name: Anisha Kumari Kushwaha
#
# References
# ---
# List the resources you consulted to complete this homework here. Write one sentence per resource about what it provided to you. If you consulted no references to complete your assignment, write a brief sentence stating that this is the case and why it was the case for you.
#
# https://docs.cohere.com/docs/controlling-generation-with-top-k-top-p
#
# Read what topk sampling means
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.choice.html
#
# To check syntak and usage of few numpy functions
#
# (Example)
# - https://docs.python.org/3/tutorial/datastructures.html
#     - Read about the the basics and syntax for data structures in python.
#
#
# AI Collaboration
# ---
# Following the *AI Collaboration Policy* in the syllabus, please cite any LLMs that you used here and briefly describe what you used them for. Additionally, provide comments in-line identifying the specific sections that you used LLMs on, if you used them towards the generation of any of your answers.
#
# Reflection
# ----
# Answer the following questions __after__ you complete this assignment (no more than 1 sentence per question required, this section is graded on completion):
#
# 1. Does this work reflect your best effort?
# YES
#
#
# 2. What was/were the most challenging part(s) of the assignment?
#
# Understanding the concept of Top k sampling and Temperature.
#
#
# 3. If you want feedback, what function(s) or problem(s) would you like feedback on and why?
#
# I would like to get feed back om top k sampling as it was kinda confusing how to calculate and renormalize the values.

# %% [markdown]
# Task 1: Large Language Models Experiments (20 points)
# ---
#
# Sign up for an account at [goose.ai](https://goose.ai), then navigate to the AI Playground. You can use any of the GPT-X models for this task. Your goal is to get the models that you play with to tell a coherent story where you are the main character. Once you have the story that allows you to answer the questions below, copy and paste it into your document. Note that you may not be "successful" in your goal to have the model tell a truly coherent story—that's okay.
#
# You'll be playing with various hyperparameters with these experiments. A hyperparameter is a parameter of a model that is manually set and controls some aspect of either the learning algorithm or the output algorithm.

# %% [markdown]
# Model: GPT-NeoX 20B
#
# Temperature: changed from 1 to 2.73 then to 0.7
#
# Top-K Sampling: changed from 0 to 38 then to 70
#
# <mark>temp: 1</mark>, <span style="background-color:red">tTop-K: 0</span>
#
# __Once I was walking to my class during early spring__ break, a few new students were walking toward me. A very nice-looking guy who was with them stopped, looked right, __stopped for few seconds and then went with his group__.
#
# When he stopped, he went back and smiled at me and then said, Thank you. He said that there weren't __any cafes nearby__. When I replied that there was one about a 7 minutes walk away, he was very surprised and said, you don't know __that it is closed for a month__. I said that I didn't know that, but yes, I remembered going there with my friend last Friday. And he was __said, do wanna go there anytime with him as he can't find it__. It really surprised me how people could not find this place, as they all had gone there on Friday and all their friends had __visited that place very often__.
#
# <mark>temp: 2.73</mark>, <span style="background-color:red">tTop-K: 38</span>
#
# While coming home in spring, with a class having afternoon meeting of 10 students I found the place was opened from 11' O __clock to night 2am__. A lovely little pub run by people called Jenna is just below our window of office floor 2 nd floor
# My new love __is spending time in the pub which has great vibe with all the lightings and melody songs.__ All students and staff there are wonderful!!
#
#
#
# __If I am going to work__ near that location during those evenings that will be good as __having break from my stressful life. Going to the pub helps me relax and enjoy my time there__. But this was so amazing that I also wanted that I may work somewhere else from where I usually go by chance I took break __from my regular class.__
#
#
#
# <mark>temp: 0.7</mark>,
# <span style="background-color:red">tTop-K: 70</span>
#
# __thought it will take sometime to be in the phase with fall__, It really takes like autumn never even a time frame of around 7, 21 was enough to catchup winter or like in Aut. This coldness lasted 5 whole months.
#
#
#
# __it snowed pretty much, this year compared to the last year. I had snow ball fight with my friends. We build snow man as well.__  ****************.. It have's been 14 February' since i post before that the word was cold cold cold' no i cannot compare any fall that much and summer and spring were pretty okay so let call autumn, winter as my hikes winter 2012 end this. __I would want to snow surfing next year though. It's been on my list for so long__ a big snow is an achievement i believe that you see ust by you. Snow white also as i get so excited to paint stuff izzizz this will need too because then only winter wiz backkkk
# but now igg have another challenge: cold that need mez winter is over so for to have fun this autumn 2012 i am excited. At most it's too cool so the days should' n e; have days below n 30 C, s r 1, then i mean __is that winter is good.__ If it 'go e be funky when fall' this month when does be end already is kinda toooooo cool it takes

# %% [markdown]
# 1. Highlight in <mark>yellow</mark> demonstrations of changing the temperature hyperparameter. To do this in markdown, `<mark>yellow highlighted text here</mark>`.
# 2. Highlight in <span style="background-color:red">red</span> demonstrations of changing the top-k hyperparameter. To do this in markdown, `<span style="background-color:red">red text here</span>`.
# 3. Indicate a demonstration of the probabilistic nature of the output of LLMs by *italicizing* at least two spans of text demonstrating identifiable probabilistic output.
#
# If background colors are not rendering in your IDE, you may alternatively use 🔥 emojis around temperature and 🔴s around top-k.

# %% [markdown]
# Task 2: Create Hyperparameter Demonstrations (15 points)
# ----
#
# (python) Create a demonstration in a jupyter notebook of changing a temperature hyperparameter. To do this, follow the steps below:
# choose an "input sequence" of 2 - 5 words to ground your example.
# 1. define a vocabulary of size >= 10
# 2. for each item in the vocabulary, choose a float, $z_i$ in the range of [-1, 1] . Generally speaking, you'll want words with higher probabilities to have a number closer to 1, words with lower probabilities to have a number closer to -1.
# 3. implement a `softmax` function (equation written below), calculate and display your starting probability distribution where $e$ is the math value $e$ (`math.e`), $z_i$ is the value you chose in step 2 for the target word, and $j$ goes through all words in your vocabulary (this is the sum of $e$ raised to the power of all your $z$ values). You should end up with a well-formed probability distribution. This probability distribution should reflect reasonable probabilities for your vocabulary given your input sequence.
# $$ \texttt{softmax}(z_i) = \frac{e^{z_i}}{\sum_{j = 1}^k e^{z_j}}$$
# 4. Add a temperature parameter ($\tau$) to your softmax function (equation below) and demonstrate the results of raising and lowering the temperature. For your demonstration, you may create a table, a series of graphs, a single graph—choose something that appropriately displays the effects of lowering the temperature below 1, temperature at 1, and temperature above 1. Your demonstration must be *easily interpretable* and *accurate*.
# $$ \texttt{softmax}(z_i, \tau) = \frac{e^{\frac{z_i}{\tau}}}{\sum_{j = 1}^k e^{\frac{z_j}{\tau}}}$$
# 5. __6120 REQUIRED__ (python) create a demonstration of changing the top-k parameter, using the same vocabulary and probability distributions that you defined in the previous question.
#     1. To complete this task, you will need to write a function that actually samples the next word from your vocabulary (we'll only do one) and that takes a parameter to represent top k.
#     2. Top k defines the number of words we will consider from the vocabulary when choosing the next word (take the k most likely), then re-normalizes the distribution to only consider these words.
#     3. Demonstrate using your sampling function with different values for top-k, showing both the top-k sampled distribution and the next word that is ultimately chosen.

# %%
# YOUR CODE HERE
# import the necessary packages
# include appropriate doc strings for functions
# add more cells as needed/desired

import numpy as np
import matplotlib.pyplot as plt

words = ["in", "school", "sky", "pretty", "moon", "awesome", "kind", "rain", "fall", "start"]

z = np.random.uniform(-1,1,len(words))

def softmax(z, temp = 1):
    ez = np.exp(z/temp)
    sum_ez = np.sum(ez)
    sftmz = ez/sum_ez
    return sftmz 


sftmx = softmax(z)
print("Softmax values for each word: ",sftmx)
    
temperature = [0.23, 1, 1.85]

for t in temperature:
    sm_z_t = softmax(z,t)
    plt.plot(sm_z_t, label = t)
    
# Plotting graph for Softmax Values with different temperatures
plt.xlabel('Vocabulary')
plt.ylabel('Softmax values')
plt.title('Softmax Values with different temperatures ')   

plt.legend()
plt.show()
# Out:
# Softmax values for each word:  [0.17521709 0.07730305 0.03142561 0.14298526 0.09919284 0.0287947
#  0.13050874 0.14442511 0.05103216 0.11911544]

# %%
# C. Changing the top-k parameter
import random
def topKSampling(k):
    topIndices = np.argsort(sftmx)[::-1][:k]
    selectedWords = [words[i] for i in topIndices]
    selectedProb = [sftmx[i] for i in topIndices]
    sumTopK = sum(selectedProb)
    for j in range(len(selectedProb)):        
        selectedProb[j] /= sumTopK        
    choosenWord = random.choices(selectedWords, weights=selectedProb)
    print("\n","Top K value: ", k)
    print("Top K Words: ",selectedWords )
    print("Probability of Top K Words: ",selectedProb)
    print("Selceted Word: ", choosenWord)
    
topK = [1,2,3,5]
for k in topK:
    topKSampling(k)
# Out:
#  Top K value:  1
# Top K Words:  ['in']
# Probability of Top K Words:  [1.0]
# Selceted Word:  ['in']
#
#  Top K value:  2
# Top K Words:  ['in', 'rain']
# Probability of Top K Words:  [0.5481663242811029, 0.45183367571889704]
# Selceted Word:  ['rain']
#
#  Top K value:  3
# Top K Words:  ['in', 'rain', 'pretty']
# Probability of Top K Words:  [0.37874337900102983, 0.3121844693992451, 0.30907215159972506]
# Selceted Word:  ['pretty']
#
#  Top K value:  5
# Top K Words:  ['in', 'rain', 'pretty', 'kind', 'start']
# Probability of Top K Words:  [0.2460044702606981, 0.20277258765748504, 0.20075104976664898, 0.18323402675024106, 0.16723786556492684]
# Selceted Word:  ['rain']

# %% [markdown]
# Task 3: Large Language Models Philosophy & Considerations (15 points)
# ----
#
# 1. Make an argument for when a computer might be reasonably considered to "know" a word. Identify at least 3 components in your argument. Justify this choice. (4 - 6 sentences)
#
#
#
# a. Context:  Computer might be reasonably considered to "know" a word if it understs the  context of a word, which makes computer to interpret the word correctly, and making the word more meaningful.
#
# b. Encounter frequently:  Encountering same word frequently improves the familiarity to the word and is easily recognized and Computer might be reasonably considered to "know" that word.
#
# c. Usage Ability: Ability to use the word in communication indicates the system has knowledge about practical application of the word.

# %% [markdown]
# 2. From your current understanding of LLMs and the definition that you just proposed, do LLMs "know" words? (2 - 4 sentences)
#
# I believe that current understanding of LLMs comes from training the model from vast data available from various sources. And through understanding context, encountering the words frequently and knowing the usability of the words, LLMs can be said to know the words. But it is also true that sometimes a model might make mistakes and intepret the word differently if the training data is misleading.

# %% [markdown]
# 3. Given what you have learned about LLMs so far, what do you think the most important thing for people to understand about LLMs is? Justify your answer. (3 - 5 sentences)
#
# Understanding that LLMs generate language based on patterns and statistics rather than on actual, meaning of word as humans do is something we need to remind ourself. Users must take responsibility when applying them, be aware of their biases, mistakes, and limitations (as it relys on training data), and rely on them as tools rather than as sources of true knowledge.

# %% [markdown]
# 5 points in this assignment are reserved for overall style (both for writing and for code submitted). All work submitted should be clear, easily interpretable, and checked for spelling, etc. (Re-read what you write and make sure it makes sense). Course staff are always happy to give grammatical help (but we won't pre-grade the content of your answers).
